# %%
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("default of credit card clients.xls",skiprows=1)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30000, step=1)

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'target'],
#       dtype='object')

# %%
df['target'] =df['default payment next month']

# %%
df.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# ...

# %%
sns.displot(df['target'])

# %%
sns.countplot(df['target'])
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
sns.countplot(df['SEX'])
# Out:
# <AxesSubplot:xlabel='SEX', ylabel='count'>

# %%
sns.boxplot(data=df,x='target',y='PAY_AMT2')3
# Out:
# <AxesSubplot:xlabel='target', ylabel='PAY_AMT2'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df,x='target',y='AGE')
# Out:
# <AxesSubplot:xlabel='target', ylabel='AGE'>

# %%
plt.figure(figsize=(10,10))
sns.histplot(x='EDUCATION',y='LIMIT_BAL',data=df)
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='LIMIT_BAL'>

# %%
sns.displot(df['EDUCATION'])

# %%
sns.boxplot(data=df,x='target',y='EDUCATION')
# Out:
# <AxesSubplot:xlabel='target', ylabel='EDUCATION'>

# %%
df.drop('default payment next month',axis=1,inplace=True)

# %%
df.drop("ID",axis=1,inplace=True)

# %%
df
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
# ...

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# target       0
# dtype: int64

# %%
df

# %%
X = df.drop('target',axis=1)
y = df.target

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *
from sklearn.model_selection import GridSearchCV,cross_val_score,train_test_split
from ipywidgets import interact
import warnings
warnings.filterwarnings('ignore')

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=1)

# %%
y_train.value_counts()
# Out:
# 0    18701
# 1     5299
# Name: target, dtype: int64

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import *
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.tree import *

# %%
y_test.value_counts()
# Out:
# 0    4663
# 1    1337
# Name: target, dtype: int64

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(x_train) ## Predicting on training data
y_test_pred = model.predict(x_test)

# %%
y_train_prob = model.predict_proba(x_train)[:,1]
y_test_prob = model.predict_proba(x_test)[:,1]

# %%
y_train_prob = model.predict_proba(x_train)
y_test_prob = model.predict_proba(x_test)

# %%
## point statistics
th = 0.40
y_train_pred = np.where(y_train_prob > th,1,0)
y_test_pred = np.where(y_test_prob > th,1,0)
print('Train:\n')
print(classification_report(y_train,y_train_pred))
print('Test:\n')
print(classification_report(y_test,y_test_pred))
# Out:
# Train:
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82     18701
#            1       0.37      0.35      0.36      5299
#
#     accuracy                           0.72     24000
#    macro avg       0.59      0.59      0.59     24000
# weighted avg       0.72      0.72      0.72     24000
#
# Test:
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83      4663
#            1       0.38      0.37      0.37      1337
#
#     accuracy                           0.73      6000
#    macro avg       0.60      0.60      0.60      6000
# weighted avg       0.72      0.73      0.73      6000

# %%
p,r,t = precision_recall_curve(y_train,y_train_prob)

# %%
sns.lineplot(t,p[:-1],label='Precision')
sns.lineplot(t,r[:-1],label='Recall')
plt.axvline(0.40,linestyle='--')
